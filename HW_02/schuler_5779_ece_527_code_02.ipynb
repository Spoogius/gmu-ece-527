# %% [markdown]
# # GMU ECE 527 - Computer Exercise #2 - Code
# **Stewart Schuler - G01395779**\
# **20240912**

# %% [markdown]
# Global imports and define PLA functions

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

np.random.seed(1)

newpath = './figures/' 
if not os.path.exists(newpath):
    os.makedirs(newpath)

def perceptron_sgd(X, y):
    w = np.zeros(len(X[0]))
    eta = 1
    epochs = 20
    for t in range(epochs):
        for i, x in enumerate(X):
            if (np.dot(X[i], w)*y[i]) <= 0:
                w = w + eta*X[i]*y[i]
    return w
                
def perceptron_sgd_pocket(X, y):
    w = np.zeros(len(X[0]))
    w_pocket = w
    pocket_score = 0
    eta = 1
    epochs = 20
    for t in range(epochs):
        for i, x in enumerate(X):
            if (np.dot(X[i], w)*y[i]) <= 0:
                w = w + eta*X[i]*y[i]
                tmp_score = perceptron_eval(X,y,w)
                if(  tmp_score > pocket_score ):
                    pocket_score = tmp_score
                    w_pocket = w
    return w_pocket
                
def perceptron_eval(X,y,w):
    num_correct = 0
    for ii in range(X.shape[0]):
        if (np.dot(X[ii],w)*y[ii]) > 0:
            num_correct+=1
    return num_correct/X.shape[0]

# %% [markdown]
# Generate separable test dataset

# %%
# Set random seed
np.random.seed(5)

# Generate Two class gausian data
N = int(200)
X = np.zeros((N,2))
X[0:int(N/2):1, 0:2:1] = np.random.normal([-1,0], [1,1], (int(N/2),2)) #X Class -1
X[int(N/2):N:1, 0:2:1] = np.random.normal([1,0], [1,1], (int(N/2),2)) #X Class 1
y = np.zeros((N,1))
y[0:int(N/2):1,:] = 1
y[int(N/2):N:1,:] = -1

# Randomize data order
rand_perm = np.random.permutation(N)
X = X[rand_perm]
y = y[rand_perm]

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.9, edgecolors='black')

# %% [markdown]
# Run SGD and Pocket and Plot result boundary

# %%
w = perceptron_sgd(X, y)
slope = -(w[0])/(w[1])

x_min = min(X[:,0])
x_max = max(X[:,0])

w_pocket = perceptron_sgd_pocket(X, y)
slope_pocket = -(w_pocket[0])/(w_pocket[1])

plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.9, edgecolors='black')
plt.plot( [x_min, x_max], [slope*x_min,slope*x_max], label=f"SGD Boundary = {perceptron_eval(X,y,w)}")
plt.plot( [x_min, x_max], [slope_pocket*x_min,slope_pocket*x_max], label=f"Pocket Boundary = {perceptron_eval(X,y,w_pocket)}")
plt.legend()
plt.xlim([x_min*1.1,x_max*1.1])
plt.ylim([min(X[:,1])*1.1,max(X[:,1])*1.1])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.savefig('figures/SGD_v_Pocket_overlap.jpg')

# %% [markdown]
# Run SGD and Pocket and Plot result boundary for a data set with an offset

# %%
# Generate Two class gausian data
N = int(200)
X = np.zeros((N,3))
X[0:N:1, 0] = 1
X[0:int(N/2):1, 1:3:1] = np.random.normal([0,0], [4,1], (int(N/2),2)) #X Class -1
X[int(N/2):N:1, 1:3:1] = np.random.normal([5,5], [3,2], (int(N/2),2)) #X Class 1
y = np.zeros((N,1))
y[0:int(N/2):1,:] = 1
y[int(N/2):N:1,:] = -1

# Randomize data order
rand_perm = np.random.permutation(N)
X = X[rand_perm]
y = y[rand_perm]

w = perceptron_sgd(X, y)
slope = -(w[1])/(w[2])
inter = -w[0]/w[2]

w_pocket = perceptron_sgd_pocket(X, y)
slope_pocket = -(w_pocket[1])/(w_pocket[2])
inter_pocket = -w_pocket[0]/w_pocket[2]

x_min = min(X[:,1])
x_max = max(X[:,1])

plt.scatter(X[:, 1], X[:, 2], c=y, alpha=0.9, edgecolors='black')
plt.plot( [x_min, x_max], inter + [slope*x_min,slope*x_max], label=f"SGD Boundary = {perceptron_eval(X,y,w)}")
plt.plot( [x_min, x_max], inter_pocket + [slope_pocket*x_min,slope_pocket*x_max], label=f"Pocket Boundary = {perceptron_eval(X,y,w_pocket)}")
plt.legend()
#plt.xlim([x_min*1.1,x_max*1.1])
#plt.ylim([min(X[:,2])*1.1,max(X[:,2])*1.1])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.savefig('figures/SGD_v_Pocket_min_overlap.jpg')

# %% [markdown]
# Create Dataset 1

# %%
import numpy as np

N = 100
X1 = np.random.rand(N,2)
y1 = (-0.5*X1[:,0] + X1[:,1] - 0.25 > 0).astype(int)
plt.scatter(X1[:, 0], X1[:, 1], c=y1, alpha=0.9, edgecolors='black')

# %% [markdown]
# Create Dataset 2

# %%
N = 100
X2 = np.random.rand(N,2)
y2 = (X2[:,1] > 4*(X2[:,0] -0.5)**2).astype(int)
plt.scatter(X2[:, 0], X2[:, 1], c=y2, alpha=0.9, edgecolors='black')

# %% [markdown]
# Create Dataset 3

# %%
from sklearn.datasets import make_moons
X3, y3 = make_moons(N,noise=0.1)
plt.scatter(X3[:, 0], X3[:, 1], c=y3, alpha=0.9, edgecolors='black')

# %% [markdown]
# Create Dataset 4

# %%
from sklearn.datasets import make_circles
X4, y4 = make_circles(N,noise=0.1, factor=0.5)
plt.scatter(X4[:, 0], X4[:, 1], c=y4, alpha=0.9, edgecolors='black')

# %% [markdown]
# Question: Does PLA work with y=0/1. Or do they need to be converted to -1/1? Does perceptron care?\
# PLA with $y \in [0,1]$

# %%
X1_pla = np.zeros((N,3))
X1_pla[:,0] = 1
X1_pla[:,1:3] = X1.copy();

w = perceptron_sgd(X1_pla, y1)
slope = -(w[1])/(w[2])
inter = -w[0]/w[2]

x_min = min(X1_pla[:,1])
x_max = max(X1_pla[:,1])

plt.scatter(X1_pla[:, 1], X1_pla[:, 2], c=y1, alpha=0.9, edgecolors='black')
plt.plot( [x_min, x_max], inter + [slope*x_min,slope*x_max], label=f"SGD Boundary = {perceptron_eval(X1_pla,y1,w)}")
plt.legend()
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title("PLA With y1 [0,1]")
plt.savefig('figures/PLA_01.jpg')

# %% [markdown]
# PLA with $y \in [-1,1]$

# %%
y1_m1 = y1.copy()
y1_m1[np.where(y1_m1==0)[0]] = -1

w = perceptron_sgd(X1_pla, y1_m1)
slope = -(w[1])/(w[2])
inter = -w[0]/w[2]

x_min = min(X1_pla[:,1])
x_max = max(X1_pla[:,1])

plt.scatter(X1_pla[:, 1], X1_pla[:, 2], c=y1_m1, alpha=0.9, edgecolors='black')
plt.plot( [x_min, x_max], inter + [slope*x_min,slope*x_max], label=f"SGD Boundary = {perceptron_eval(X1_pla,y1_m1,w)}")
plt.legend()

plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title("PLA With y1 [-1,1]")
plt.savefig('figures/PLA_-11.jpg')

# %% [markdown]
# Perceptron with $y \in [0,1]$ Same parameters

# %%
from sklearn.linear_model import Perceptron
clf = Perceptron(fit_intercept=True, eta0=1, max_iter=20, n_iter_no_change=20 )
clf.fit(X1,y1)

w = clf.coef_[0]
w = np.array([clf.intercept_[0],w[0],w[1]])
slope = -(w[1])/(w[2])
inter = -w[0]/w[2]

x_min = min(X1[:,0])
x_max = max(X1[:,0])

plt.scatter(X1[:, 0], X1[:, 1], c=y1, alpha=0.9, edgecolors='black')
plt.plot( [x_min, x_max], inter + [slope*x_min,slope*x_max])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title("Perceptron With y1 [0,1]")
plt.savefig('figures/Perceptron_01.jpg')
# Out:
# C:\Users\Stewart\Documents\GMU\gmu-ece-527\env_39\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:744: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(

# %% [markdown]
# Perceptron with $y \in [-1,1]$ Same parameters

# %%
from sklearn.linear_model import Perceptron
clf = Perceptron(fit_intercept=True, eta0=1, max_iter=20, n_iter_no_change=20 )
clf.fit(X1,y1_m1)

w = clf.coef_[0]
w = np.array([clf.intercept_[0],w[0],w[1]])
slope = -(w[1])/(w[2])
inter = -w[0]/w[2]

x_min = min(X1[:,0])
x_max = max(X1[:,0])

plt.scatter(X1[:, 0], X1[:, 1], c=y1_m1, alpha=0.9, edgecolors='black')
plt.plot( [x_min, x_max], inter + [slope*x_min,slope*x_max])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title("Perceptron With y1 [-1,1]")
plt.savefig('figures/Perceptron_-11.jpg')
# Out:
# C:\Users\Stewart\Documents\GMU\gmu-ece-527\env_39\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:744: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(

# %% [markdown]
# ## Dataset Experiments

# %%
from sklearn.model_selection import train_test_split

eta0 = 0.25
tol = 5E-6;

for dataset_idx in range(4):
    if dataset_idx == 0:
        dataset_x = X1.copy();
        dataset_y = y1.copy();
        dataset_num = 1;
    elif dataset_idx == 1:
        dataset_x = X2.copy();
        dataset_y = y2.copy();
        dataset_num = 2;
    elif dataset_idx == 2:
        dataset_x = X3.copy();
        dataset_y = y3.copy();
        dataset_num = 3;
    elif dataset_idx == 3:
        dataset_x = X4.copy();
        dataset_y = y4.copy();
        dataset_num = 4;

    dataset_y[np.where(dataset_y==0)[0]] = -1

    print(dataset_num)
    X_train, X_test, y_train, y_test = train_test_split(dataset_x,dataset_y, test_size=0.20)
    
    clf = Perceptron(fit_intercept=True, eta0=eta0,random_state=1, tol=tol )
    clf.fit(X_train,y_train)
    
    w = clf.coef_[0]
    w = np.array([clf.intercept_[0],w[0],w[1]])
    slope = -(w[1])/(w[2])
    inter = -w[0]/w[2]
    
    print(f"Training iterations: {clf.n_iter_}")
    
    n_epoch = 50
    epoch_score_train = np.zeros((n_epoch))
    epoch_score_test = np.zeros((n_epoch))
    clf_curve = Perceptron(fit_intercept=True, eta0=eta0,random_state=1, tol=tol )
    for epoch_itr in range(n_epoch):
        clf_curve.partial_fit(X_train, y_train, classes=np.unique(y1_m1))
        epoch_score_train[epoch_itr] = 1-clf_curve.score(X_train, y_train)
        epoch_score_test[epoch_itr] = 1-clf_curve.score(X_test, y_test)
    
    plt.figure()
    plt.plot(np.linspace(1,n_epoch,n_epoch), epoch_score_train, label="Train Error Rate")
    plt.plot(np.linspace(1,n_epoch,n_epoch), epoch_score_test, label="Test Error Rate")
    plt.legend()
    plt.title(f"Dataset {dataset_num} learning curve")
    plt.savefig(f'figures/dataset_{dataset_num}_learning_curve.jpg')
    
    X_train_offset = np.append(np.zeros((X_train.shape[0],1))+1, X_train, axis=1)
    X_test_offset  = np.append(np.zeros((X_test.shape[0] ,1))+1, X_test,  axis=1)
    
    w_pocket = perceptron_sgd_pocket(X_train_offset, y_train)
    slope_pocket = -(w_pocket[1])/(w_pocket[2])
    inter_pocket = -w_pocket[0]/w_pocket[2]
    
    #print(X1_test_score)
    #print(y1_test)
    x_min = min(X_test[:,0])
    x_max = max(X_test[:,0])
    
    plt.figure()
    plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, alpha=0.9, edgecolors='black')
    plt.plot( [x_min, x_max], inter + [slope*x_min,slope*x_max], label=f"Decision Boundary = {clf.score(X_test,y_test)}")
    #plt.plot( [x_min, x_max], inter_pocket + [slope_pocket*x_min,slope_pocket*x_max], label=f"Pocket Decision Boundary = {perceptron_eval(X_test_offset, y_test, w_pocket)}")
    plt.legend()
    plt.xlabel('$x_1$')
    plt.ylabel('$x_2$')
    plt.title(f"Dataset {dataset_num} Test Set")
    plt.savefig(f'figures/dataset_{dataset_num}_pla.jpg')
    
    plt.figure()
    
    # Test Different random seeds
    plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, alpha=0.9, edgecolors='black')
    for seed in range(5):
        #np.random.seed(seed)
        clf = Perceptron(fit_intercept=True, eta0=eta0, random_state=seed, tol=tol)
        clf.fit(X_train,y_train)
        
        w = clf.coef_[0]
        w = np.array([clf.intercept_[0],w[0],w[1]])
        slope = -(w[1])/(w[2])
        inter = -w[0]/w[2]
        plt.plot( [x_min, x_max], inter + [slope*x_min,slope*x_max], label=f"Seed = {seed}")

    
    plt.title(f"Set {dataset_num} Seed variation on Test Set")
    plt.legend()
    plt.savefig(f'figures/dataset_{dataset_num}_seed_variation.jpg')
# Out:
# 1
# Training iterations: 8
# 2
# Training iterations: 10
# 3
# Training iterations: 12
# 4
# Training iterations: 6

# %% [markdown]
# # Computer Exercise 2.2

# %% [markdown]
# **Dataset 2**

# %%
from sklearn.preprocessing import PolynomialFeatures
import math


poly2 = PolynomialFeatures( degree=2, include_bias=True )
X2_aug = poly2.fit_transform(X2)
print(X2_aug.shape)
clf = Perceptron(fit_intercept=False, eta0=0.1, tol=1E-6)
clf.fit(X2_aug,y2)
w = clf.coef_[0]
print(clf.coef_[0])
print(clf.intercept_[0])

x_min = min(X2[:,0])
x_max = max(X2[:,0])
y_min = min(X2[:,1])
y_max = max(X2[:,1])

N_G = 100
x_plt = np.linspace(x_min,x_max, N_G)
y_plt = np.zeros((N_G))
y_plt_1 = np.zeros((N_G))
y_plt_2 = np.zeros((N_G))

# https://www.wolframalpha.com/input?i=0+%3D+a+%2B+b*x+%2B+c*y+%2B+d*x%5E2+%2B+e*x*y+%2B+f*y%5E2+solve+for+y
for idx, x_val  in enumerate(x_plt):
    #y_plt[idx] = -(w[0]+x_val*(w[1]+w[3]*x_val))/(w[2]+w[4]*x_val)
    y_plt[idx] = -(w[2]+w[4]*x_val-math.sqrt((w[2]+w[4]*x_val)**2-4*w[5]*(w[0]+x_val*(w[1]+w[3]*x_val))))/(2*w[5]);
    
plt.figure()
plt.scatter(X2[:, 0], X2[:, 1], c=y2, alpha=0.9, edgecolors='black')
plt.plot( x_plt, y_plt, label=f"Decision Boundary = {clf.score(X2_aug,y2)}")
plt.savefig("figures/dataset_2_poly.jpg")
plt.legend()
scale = 0.2;
plt.xlim([x_min-scale,x_max+scale])
plt.ylim([y_min-scale,y_max+scale])
print(f"Dataset 2 Score = {clf.score(X2_aug,y2)}")
# Out:
# (100, 6)
# [-0.2         0.77600669  0.00193916 -1.01714386  0.58881136  0.18292577]
# 0.0
# Dataset 2 Score = 0.9

# %% [markdown]
# **Dataset 3**

# %%
poly3 = PolynomialFeatures( degree=3, include_bias=True )
X3_aug = poly3.fit_transform(X3)
print(X3_aug.shape)
clf = Perceptron(fit_intercept=False, eta0=0.1, tol=1E-6)
clf.fit(X3_aug,y3)
w = clf.coef_[0]
print(w)

print(f"Dataset 3 Score = {clf.score(X3_aug,y3)}")
# Out:
# (100, 10)
# [ 0.5        -0.68688094 -0.45452222 -0.82305651 -0.32260773  0.0179445
#   0.8576777  -0.38392009  0.19430991 -0.29674405]
# Dataset 3 Score = 0.99

# %% [markdown]
# **Dataset 4**

# %%
X4_aug = np.zeros( (X4.shape[0], 3))
X4_aug[:,0] = 1
X4_aug[:,1] = X4[:,0]**2
X4_aug[:,2] = X4[:,1]**2
print(X4_aug.shape)

clf = Perceptron(fit_intercept=False, eta0=0.1, tol=1E-6)
clf.fit(X4_aug,y4)
w = clf.coef_[0]
print(w)
print(f"Dataset 4 Score = {clf.score(X4_aug,y4)}")
# Out:
# (100, 2)
# [ 0.02257664 -0.02102361]
# Dataset 4 Score = 0.49

# %% [markdown]
# **Apply higher order to dataset 1**

# %%
# 2nd Degree
poly2 = PolynomialFeatures( degree=2, include_bias=True )
X1_aug = poly2.fit_transform(X1)

clf = Perceptron(fit_intercept=False, eta0=0.1, tol=1E-6)
clf.fit(X1_aug,y1)
print(f"Dataset 1 Poly 2 Score = {clf.score(X1_aug,y1)}")

# 3rd Degree
poly3 = PolynomialFeatures( degree=3, include_bias=True )
X1_aug = poly3.fit_transform(X1)

clf = Perceptron(fit_intercept=False, eta0=0.1, tol=1E-6)
clf.fit(X1_aug,y1)
print(f"Dataset 1 Poly 3 Score = {clf.score(X1_aug,y1)}")

# Circle
X1_aug = np.zeros( (X1.shape[0], 3))
X1_aug[:,0] = 1
#X1_aug[:,1:3] = X1.copy()
X1_aug[:,1] = X1[:,0]**2
X1_aug[:,2] = X1[:,1]**2
clf = Perceptron(fit_intercept=False, eta0=0.1, tol=1E-6)
clf.fit(X1_aug,y1)
print(f"Dataset 1 Circle Score = {clf.score(X1_aug,y1)}")

# Sin cos
X1_aug = np.zeros( (X1.shape[0], 3))
X1_aug[:,0] = 1
#X1_aug[:,1:3] = X1.copy()
X1_aug[:,1] = np.array([math.sin(X1[ii,0]) for ii in range(X1.shape[0])])
X1_aug[:,2] = np.array([math.cos(X1[ii,0]) for ii in range(X1.shape[0])])
clf = Perceptron(fit_intercept=False, eta0=0.1, tol=1E-6)
clf.fit(X1_aug,y1)
print(f"Dataset 1 Sin/Cos Score = {clf.score(X1_aug,y1)}")
# Out:
# Dataset 1 Poly 2 Score = 0.98
# Dataset 1 Poly 3 Score = 1.0
# Dataset 1 Circle Score = 0.98
# Dataset 1 Sin/Cos Score = 0.43

# %% [markdown]
# Plot of Poly2 on dataset 1

# %%
poly2 = PolynomialFeatures( degree=2, include_bias=True )
X1_aug = poly2.fit_transform(X1)

clf = Perceptron(fit_intercept=False, eta0=0.1, tol=1E-6)
clf.fit(X1_aug,y1)
w = clf.coef_[0]
print(clf.coef_[0])
print(clf.intercept_[0])

x_min = min(X1[:,0])
x_max = max(X1[:,0])
y_min = min(X1[:,1])
y_max = max(X1[:,1])

N_G = 100
x_plt = np.linspace(x_min,x_max, N_G)
y_plt = np.zeros((N_G))
y_plt_1 = np.zeros((N_G))
y_plt_2 = np.zeros((N_G))

# https://www.wolframalpha.com/input?i=0+%3D+a+%2B+b*x+%2B+c*y+%2B+d*x%5E2+%2B+e*x*y+%2B+f*y%5E2+solve+for+y
for idx, x_val  in enumerate(x_plt):
    #y_plt[idx] = -(w[0]+x_val*(w[1]+w[3]*x_val))/(w[2]+w[4]*x_val)
    y_plt[idx] = -(w[2]+w[4]*x_val-math.sqrt((w[2]+w[4]*x_val)**2-4*w[5]*(w[0]+x_val*(w[1]+w[3]*x_val))))/(2*w[5]);
    
plt.figure()
plt.scatter(X1[:, 0], X1[:, 1], c=y1, alpha=0.9, edgecolors='black')
plt.plot( x_plt, y_plt, label=f"Decision Boundary = {clf.score(X1_aug,y1)}")
plt.legend()
scale = 0.2;
plt.xlim([x_min-scale,x_max+scale])
plt.ylim([y_min-scale,y_max+scale])
plt.title("2nd order poly")
plt.savefig("figures/dataset_1_poly_2.jpg")
# Out:
# [-0.1        -0.44964765  0.40552779 -0.15320543  0.12862014  0.55888878]
# 0.0

# %%
poly3 = PolynomialFeatures( degree=3, include_bias=True )
X1_aug = poly3.fit_transform(X1)

clf = Perceptron(fit_intercept=False, eta0=0.1, tol=1E-6)
clf.fit(X1_aug,y1)
w = clf.coef_[0]
print(f"Score = {clf.score(X1_aug,y1)}")
# Out:
# Score = 1.0
